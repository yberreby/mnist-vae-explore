# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %run explore.py
# Out:
# interactive(children=(IntSlider(value=0, description='idx1', max=9999), IntSlider(value=1, description='idx2',…
# interactive(children=(IntSlider(value=0, description='idx', max=9999), FloatSlider(value=0.5, description='std…
